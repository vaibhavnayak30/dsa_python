# %% [markdown]
# ## Longest Palindromic Substring

# %%
class Solution:
    def longestPalindrome(self, s: str) -> str:
        result = ''

        # Write expand function 
        def expand(left, right):
            while left >= 0 and right < len(s) and s[left] == s[right]:
                left -= 1
                right += 1

            return s[left + 1 : right]

        # Loop
        for idx in range(len(s)):
            odd = expand(left=idx, right= idx)
            even = expand(left=idx, right= idx+1)

            longer = odd if len(odd) > len(even) else even

            if len(longer) > len(result):
                result = longer
            
        return result

# %% [markdown]
# ## Container With Most Water

# %%
class Solution:
    def maxArea(self, height: List[int]) -> int:
        # Initialise the pointers 
        left = 0
        right = len(height) - 1
        result = 0

        # Loop
        while left < right:
            # Calculate the current area 
            curr_water_content = min(height[left], height[right]) * (right - left)

            # Get the max 
            result = max(result, curr_water_content)

            # Shift the pointers 
            if height[left] < height[right]:
                left += 1
            
            else:
                right -= 1

        return result

# %% [markdown]
# ## 3 Sum

# %%
class Solution:
    def threeSum(self, nums: List[int]) -> List[List[int]]:
        
        # Main loop
        for idx, element in enumerate(nums):
            # Get slice search area 
            temp_nums = nums[idx+1:]
            # Required sum
            req_sum = -(element)


            if temp_nums:
                comp_set = set()
                for sub_element in temp_nums:
                    # Get the complementary number
                    comp_num = req_sum - sub_element

                    # Check if comp_num in set 
                    if comp_num in comp_set:
                        # Check for condition 
                        if element != sub_element and sub_element !=
                    
                    else:

# %%
class Solution:
    def maxProfit(self, prices: List[int]):
        # Initialise the variables 
        p1 = 0
        max_profit = 0

        for p2, _ in enumerate(prices):
            # Calculate the difference 
            curr_profit = prices[p2] - prices[p1]

            # Check
            if curr_profit < 0:
                p1 += 1
            else:
                max_profit = max(curr_profit, self.maxProfit)

        return max_profit
